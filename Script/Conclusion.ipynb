# %% [markdown]
# # Conclusions
#
# Now we answer the originals questions:
# 1. Can the SEARO region be divided into clusters using the K-means algorithm?
# 2. Is K-means an appropriate algorithm for this task?
# 3. Are the chosen variables adequate for obtaining meaningful results?
# 4. Which of the two clustering methods is more efficient?
# 5. How our results will be affected if we took under consideration the whole world for the years 2020,2021,2022?

# %%
# %%capture
# %run PR5_gitlab.ipynb

# %% [markdown]
# ## Question 1:

# %% [markdown]
# K-means is a popular unsupervised learning algorithm that is widely used for clustering data into k groups or clusters. The algorithm is based on the idea of minimizing the sum of the distances between the data points and the centroids of the clusters they belong to.
#
# The World Health Organization (WHO) has a dataset called 'SEARO' which stands for South-East Asia Region, that contains a wide range of health-related information for the countries of the Southeast Asia region.
#
# When using k-means to analyze this dataset, it is important to note that the scale of the different features can have a significant impact on the results of the algorithm. For example, if the scale of the different features is not taken into account, the algorithm might give more importance to the features with higher values, even if they are not the most relevant for the analysis.
#
# To address this issue, the data can be scaled before applying k-means. Scaling the data ensures that all the features have the same weight in the analysis, and it can also improve the performance of the algorithm. There are several ways to scale the data, such as Min-Max scaling, standardization, and normalization.
#
# When I use k-means on the WHO's SEARO dataset, I used Min-Max scaling, this method scales the data to a fixed range between 0 and 1. The results of the k-means algorithm on the scaled data showed slightly different clusters than the unscaled data. The cluster that was created by the scaled data was more compact and had a more homogeneous distribution of data points.
#
# In conclusion, k-means is a useful tool for analyzing the WHO's SEARO dataset as it allows identifying patterns and trends in the data. However, it is important to take the scale of the different features into account before applying the algorithm. Scaling the data can have a significant impact on the results of the k-means algorithm and can improve the performance of the algorithm.

# %%
k_means_base(3,dg,'Cumulative_cases','Cumulative_deaths','K_means_data_paper')
# Out:
#        Date_reported      Country  Cumulative_cases  Cumulative_deaths  \
# 14002     2020-04-30   Bangladesh          0.231819           0.156425
# 20410     2020-04-30       Bhutan          0.000000           0.000000
# 78082     2020-04-30        India          1.000000           1.000000
# 79150     2020-04-30    Indonesia          0.305995           0.737430
# 105850    2020-04-30     Maldives          0.011773           0.000000
# 118666    2020-04-30      Myanmar          0.004328           0.005587
# 120802    2020-04-30        Nepal          0.001513           0.000000
# 160318    2020-04-30    Sri Lanka          0.019429           0.006518
# 166726    2020-04-30     Thailand          0.089187           0.050279
# 168862    2020-04-30  Timor-Leste          0.000514           0.000000
#
#         Population  Period_deaths  Period_cases  Cases_per_Capita  \
# 14002    167310838       0.156430      0.239433          0.058928
# ...

# %%
k_means(3,dg,'Cumulative_cases','Cumulative_deaths','K_means_dati_paper_scaled')
# Out:
#        Date_reported      Country  Cumulative_cases  Cumulative_deaths  \
# 14002     2020-04-30   Bangladesh          0.231819           0.156425
# 20410     2020-04-30       Bhutan          0.000000           0.000000
# 78082     2020-04-30        India          1.000000           1.000000
# 79150     2020-04-30    Indonesia          0.305995           0.737430
# 105850    2020-04-30     Maldives          0.011773           0.000000
# 118666    2020-04-30      Myanmar          0.004328           0.005587
# 120802    2020-04-30        Nepal          0.001513           0.000000
# 160318    2020-04-30    Sri Lanka          0.019429           0.006518
# 166726    2020-04-30     Thailand          0.089187           0.050279
# 168862    2020-04-30  Timor-Leste          0.000514           0.000000
#
#         Population  Period_deaths  Period_cases  Cases_per_Capita  \
# 14002    167310838       0.156430      0.239433          0.058928
# ...

# %% [markdown]
# ## Question 2:

# %% [markdown]
# Hierarchical Birch is a clustering algorithm that is similar to k-means but with some key differences that make it useful in certain scenarios.
#
# One of the main advantages of Hierarchical Birch over k-means is its ability to handle large datasets with a high number of dimensions. k-means has a high computational cost for high-dimensional data, as it requires calculating distances between all data points and the centroids of the clusters. Hierarchical Birch, on the other hand, uses a hierarchical structure to reduce the computational cost and can handle large datasets more efficiently.
#
# Another advantage of Hierarchical Birch is that it can handle non-spherical clusters. k-means assumes that clusters are spherical, which can lead to poor results when the clusters have a different shape. Hierarchical Birch can handle clusters of different shapes and can also identify subclusters within clusters.
#
# Furthermore, Hierarchical Birch can handle noise and outliers in the data more effectively than k-means. k-means is sensitive to noise and outliers and they can have a significant impact on the results of the algorithm. Hierarchical Birch uses a CF tree to store the data points and it can handle noise and outliers by creating subclusters within clusters.
#
# In summary, Hierarchical Birch can be useful for clustering large datasets with high dimensional data, non-spherical clusters, and noise or outliers. It is a more robust algorithm than k-means and can handle these scenarios more effectively.

# %%
tree(dg,10,8,14,'hierarchical_dati_paper')
# Out:
# execution time = 0.0918431282043457

# %%
tree(il,10,8,14,'hierarchical_dati_paper_adjusted')
# Out:
# execution time = 0.018838882446289062

# %% [markdown]
# ## Question 3:

# %% [markdown]
# Making an analysis with different variables from a previous one can be useful for several reasons:
#
# Variable selection: By using a correlation matrix, you can identify which variables are strongly correlated with the outcome variable of interest. This allows you to select the most relevant variables for the analysis and exclude those that are not as informative. This can improve the accuracy of the analysis and also reduces the risk of overfitting.
#
# Dimensionality reduction: When working with high-dimensional data, it is important to reduce the number of features to prevent overfitting and improve the performance of the analysis. By selecting only the most relevant variables, you can reduce the dimensionality of the data and improve the interpretability of the results.
#
# Robustness: By using different variables in the analysis, you can test the robustness of the results. For example, if the results of the analysis are robust to different variable selections, it means that the conclusions are not affected by the specific variables that were chosen, and thus they are more reliable.
#
# Model improvement: Selecting different variables can also help in improving the performance of the model and increase its generalization capabilities.
#
# Understanding: By making an analysis with different variables, you can gain a deeper understanding of the problem. For example, you can explore how different variables are related to the outcome, identify important interactions, and gain insights that were not apparent in the initial analysis.
#
# In conclusion, making an analysis with different variables from a the ones of the paper, especially when the choice of variables is based on a correlation matrix, can help in improving the accuracy, interpretability, robustness, performance, and understanding of the problem.

# %%
corr2(dg2,'Correlation_dati_paper')
# Out:
#                    Cumulative_cases  Cumulative_deaths  Population  \
# Cumulative_cases           1.000000           0.920806    0.987213
# Cumulative_deaths          0.920806           1.000000    0.880462
# Population                 0.987213           0.880462    1.000000
# Period_deaths              0.949258           0.996497    0.916616
# Period_cases               0.998263           0.907661    0.989200
# Cases_per_Capita          -0.152161          -0.165163   -0.153150
# Death_per_Capita           0.393461           0.669041    0.269950
# cluster                    0.520229           0.651150    0.389576
#
#                    Period_deaths  Period_cases  Cases_per_Capita  \
# Cumulative_cases        0.949258      0.998263         -0.152161
# Cumulative_deaths       0.996497      0.907661         -0.165163
# Population              0.916616      0.989200         -0.153150
# Period_deaths           1.000000      0.938925         -0.163392
# ...

# %%
k_means(2,dg,'Cases_per_Capita','Death_per_Capita','K_means_data_per_capita')
# Out:
#        Date_reported      Country  Cumulative_cases  Cumulative_deaths  \
# 14002     2020-04-30   Bangladesh          0.231819           0.156425
# 20410     2020-04-30       Bhutan          0.000000           0.000000
# 78082     2020-04-30        India          1.000000           1.000000
# 79150     2020-04-30    Indonesia          0.305995           0.737430
# 105850    2020-04-30     Maldives          0.011773           0.000000
# 118666    2020-04-30      Myanmar          0.004328           0.005587
# 120802    2020-04-30        Nepal          0.001513           0.000000
# 160318    2020-04-30    Sri Lanka          0.019429           0.006518
# 166726    2020-04-30     Thailand          0.089187           0.050279
# 168862    2020-04-30  Timor-Leste          0.000514           0.000000
#
#         Population  Period_deaths  Period_cases  Cases_per_Capita  \
# 14002    167310838       0.156430      0.239433          0.058928
# ...

# %%
tree(dg,10,8,14,'hierarchical_data_per_capita')
# Out:
# execution time = 0.021709680557250977

# %% [markdown]
# ## Question 4:

# %% [markdown]
# K-means and Hierarchical clustering are two different algorithms that have their own strengths and weaknesses when it comes to handling large and small datasets.
#
# Therefore, K-means is faster for large datasets because it only needs to calculate the distances between the data points and the centroids, which is relatively fast even for large datasets. On the other hand, hierarchical clustering is faster for small datasets.

# %%
data = {'Algorithm': ['k-means', 'hierarchical', 'k-means', 'hierarchical'],
        'Data dimensionality': ['low_dimensional_data', 'low_dimensional_data', 'high_dimensional_data','high_dimensional_data'],
        'Execution Time': [0.23559188842773438, 0.01936793327331543, 0.2509911060333252,0.27199649810791016 ]}
df = pd.DataFrame(data)
display(df)
# Out:
#       Algorithm    Data dimensionality  Execution Time
# 0       k-means   low_dimensional_data        0.235592
# 1  hierarchical   low_dimensional_data        0.019368
# 2       k-means  high_dimensional_data        0.250991
# 3  hierarchical  high_dimensional_data        0.271996

# %% [markdown]
# ## Question 5:

# %% [markdown]
# Unfortunately, the hierarchical clustering method proved to be inefficient in creating a sufficient number of clusters for the large amount of data and the homogeneity among the variables of different countries. On the other hand, the K-means algorithm was able to produce 4 distinct clusters. As the year progressed, the variability of the clusters increased due to changes in the data over time. This could be attributed to variations in the management of the COVID-19 pandemic and the ability to obtain reliable data among different countries.

# %%
# %%capture
# %run world_2020.ipynb

# %%
 k_means(4,data_2020,'Cases_per_Capita','Death_per_Capita','K_means_2020')
# Out:
#        Date_reported      Country  Cumulative_cases  Cumulative_deaths  \
# 363       2020-12-31  Afghanistan          0.002673           0.006219
# 1431      2020-12-31      Albania          0.002949           0.003335
# 2499      2020-12-31      Algeria          0.005073           0.007815
# 3567      2020-12-31      Andorra          0.000408           0.000239
# 4635      2020-12-31       Angola          0.000890           0.001151
# ...              ...          ...               ...                ...
# 179787    2020-12-31      Uruguay          0.000917           0.000477
# 180855    2020-12-31   Uzbekistan          0.003936           0.001744
# 181923    2020-12-31        Yemen          0.000107           0.001736
# 182991    2020-12-31       Zambia          0.001045           0.001097
# 184059    2020-12-31     Zimbabwe          0.000696           0.001023
#
#         Population  Cases_per_Capita  Death_per_Capita  cluster
# ...

# %%
tree(data_2020,23,25,18,'hierarchical_clustering_2020')
# Out:
# execution time = 0.023415088653564453

# %%
# %%capture
# %run world_2021.ipynb

# %%
k_means(4,po,'Cases_per_Capita','Death_per_Capita','K_means_2021')
# Out:
#        Date_reported      Country  Cumulative_cases  Cumulative_deaths  \
# 728       2021-12-31  Afghanistan          0.002952           0.008981
# 1796      2021-12-31      Albania          0.003914           0.003925
# 2864      2021-12-31      Algeria          0.004073           0.007656
# 3932      2021-12-31      Andorra          0.000432           0.000171
# 5000      2021-12-31       Angola          0.001434           0.002145
# ...              ...          ...               ...                ...
# 180152    2021-12-31      Uruguay          0.007664           0.007531
# 181220    2021-12-31   Uzbekistan          0.003715           0.001813
# 182288    2021-12-31        Yemen          0.000189           0.002422
# 183356    2021-12-31       Zambia          0.004655           0.004554
# 184424    2021-12-31     Zimbabwe          0.003955           0.006101
#
#         Population  Period_deaths  Period_cases  Cases_per_Capita  \
# ...

# %%
tree(po,23,25,18,'hierarchical_data_2021')
# Out:
# execution time = 0.03406500816345215

# %%
# %%capture
# %run world_2022.ipynb

# %%
k_means(4,wo,'Cases_per_Capita','Death_per_Capita','K_means_2022')
# Out:
#        Date_reported      Country  Cumulative_cases  Cumulative_deaths  \
# 1067      2022-12-05  Afghanistan          0.002113           0.007313
# 2135      2022-12-05      Albania          0.003404           0.003355
# 3203      2022-12-05      Algeria          0.002777           0.006423
# 4271      2022-12-05      Andorra          0.000484           0.000147
# 5339      2022-12-05       Angola          0.001073           0.001797
# ...              ...          ...               ...                ...
# 180491    2022-12-05      Uruguay          0.010181           0.007036
# 181559    2022-12-05   Uzbekistan          0.002533           0.001528
# 182627    2022-12-05        Yemen          0.000122           0.002015
# 183695    2022-12-05       Zambia          0.003419           0.003752
# 184763    2022-12-05     Zimbabwe          0.002655           0.005246
#
#         Population  Period_deaths  Period_cases  Cases_per_Capita  \
# ...

# %%
tree(wo,23,25,18,'hierarchical_data_2022')
# Out:
# execution time = 0.024498939514160156

# %% [markdown]
# ## Differences between years

# %% [markdown]
# As previously said, the hierarchical birch, doesn't show any particular differences between Clusters for different Years. Due to the homogeneity of the results and the large amount of data, we troncated the Cluster in order to improve visualization. We created 12 clusters, 7 compose of single countries (China, India, USA, Indonesia, Nigeria, Bangladesh, Russia), this countries didn't change during the years. The other 5 Clusters were composed from all the rests of the Country, respectively agglomerate in cluster of 154, 2, 2, 4 and 3.
#
# On the other hand K-means show interesting results(in order to compare differents results we will refer to the term best performing as to the countries with the lowest number of death per capita and the lowest number of cases per capita due to covid):
# #### year 2020:
# As for the year 2020 we obtain 4 different clusters, in the first year of our observation cluster 0 is the best performing, cluster 2 is the second best performance, with cluster 1 as the next in line, cluster 3 prove to be the one with the highest number of death per capita, and the highest number of cases per capita(it is worth noticing that between the worst performing countries there is higher variability between death and cases performance).
# #### year 2021:
# As for the year 2021, we obtain 4 different clusters. cluster 0 is again the best performing, but as the second best performance we obtain cluster 3. With year 2021 we started to observe some interesting results as
# there is no more clear correlation between number of cases per capita and number of deaths per capita. Cluster 2 is the worst performing in terms of mortality due to the fact that is the cluster with the highest number of death per capita, even if it is not the cluster with the highest number of cases.
# Cluster 1 on the other hand show the opposite situations, in fact in terms of death per capita, can be classified as one of the best performing clusters, but in terms of cases per capita, it's clearly the worst performer. Analysing year 2021, it's not so clear if a correlation between number of cases and number of deaths can exist. This can be due to different policy choice of differents countries.
# #### year 2022:
# As for the year 2022, we still obtain 4 different clusters, and in the same way cluster 0 remains the best performing cluster, cluster 2 classify itself as the second best performing, and as for the year 2021, the remaining 2 cluster, cannot be clearly divided. Cluster 3 classify as the cluster with the highest mortality rate, while cluster 1 classify itself as the cluster with the highest number of cases. This confirms the trend started in 2021, of the lack of a linear dependance between number of death per capita, and number of cases per capita.
